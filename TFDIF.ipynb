# %%
import pandas as pd

# %%
df=pd.read_parquet('dados_estruturados_codigo_etica.parquet')

# %%
df
# Out:
#                                           Epigrafe  \
# 0    Portaria CELEPAR 170 - 09 de Setembro de 2024
# 1     Portaria FUNEAS 372 - 02 de Setembro de 2024
# 2          Portaria APPA 215 - 16 de Julho de 2024
# 3               Decreto 5512 - 16 de Abril de 2024
# 4                 Lei 21.926 - 11 de Abril de 2024
# ..                                             ...
# 148        Resolução SESA 248 - 22 de Maio de 2012
# 149      Lei Complementar 136 - 19 de Maio de 2011
# 150          Decreto 8891 - 29 de Novembro de 2010
# 151  Lei Complementar 131 - 29 de Setembro de 2010
# 152                Lei 16544 - 14 de Julho de 2010
#
#                                              Descricao Data_Publicacao
# 0    Recomposição dos membros doComitê Permanente d...      09/09/2024
# 1    Designa Comissão Provisória de Revisão e Atual...      03/09/2024
# 2    INSTITUIR COMITÊ DE CONTINGÊNCIA PARA EVENTOS ...      31/07/2024
# 3    Dispõe sobre o relacionamento da administração...      16/04/2024
# 4    Consolida a legislação paranaense relativa aos...      11/04/2024
# ..                                                 ...             ...
# 148  Instituir o Incentivo Financeiro de custeio do...      24/05/2012
# 149  Estabelece a Lei Orgânica da Defensoria Públic...      19/05/2011
# 150  Introduz alterações no Regulamento do\nICMS, a...      29/11/2010
# 151  Dispõe sobre a\nreestruturação da carreira do ...      29/09/2010
# 152  Dispõe que o processo disciplinar na Polícia M...      14/07/2010
#
# [153 rows x 3 columns]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Carregar o dataframe (no seu caso, o dataframe já está carregado)
# df = pd.read_csv('seu_arquivo.csv')

# Exemplo de texto dado pelo usuário para calcular a similaridade
texto_dado = "Instituir comitê de contingência para eventos"

# Transformar a coluna 'Epigrafe' em vetores TF-IDF
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df['Descricao'])

# Transformar o texto dado em vetor TF-IDF
tfidf_texto_dado = tfidf_vectorizer.transform([texto_dado])

# Calcular a similaridade de cosseno entre o texto dado e os textos no dataframe
similaridades = cosine_similarity(tfidf_texto_dado, tfidf_matrix)

# Adicionar a similaridade ao dataframe
df['Similaridade'] = similaridades.flatten()

# Ordenar o dataframe pelas similaridades
df_ordenado = df.sort_values(by='Similaridade', ascending=False)

# Exibir os 5 textos mais similares
print(df_ordenado[['Descricao', 'Similaridade']].head(5))
# Out:
#                                             Descricao  Similaridade
# 2   INSTITUIR COMITÊ DE CONTINGÊNCIA PARA EVENTOS ...      0.544746
# 15  Instituir o Comitê de Ética e Integridade da P...      0.206630
# 58  Designa empregados para compor o Comitê Perman...      0.177000
# 21  Recomposição dos membros do Comitê Permanente ...      0.172117
# 51  Recomposição dos membros do Comitê Permanente ...      0.172117
